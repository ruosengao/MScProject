# %%
from src import *

bm1 = BrownianMotion1D(5000, B0=0.0)
bm2 = BrownianMotion1D(5000, B0=1.0)
bm3 = BrownianMotion1D(5000, B0=-1.0)
oi1 = OpenInterval()
oi2 = OpenInterval(-2,2)
oi3 = OpenInterval(-5,5)
pr = ProcessRegister1D()
pr.add_process([bm1,bm2,bm3])
pr.add_domain([oi1,oi2,oi3])

# %%
print(pr.get_exit_time())
# Out:
# [[  nan   nan   nan]
#  [ 5.36  3.09  5.95]
#  [ 8.5  38.   59.06]]

# %%
pr.plot_full_process()
plt.show()

# %%
pr.plot_up_to_exit()
plt.show()
