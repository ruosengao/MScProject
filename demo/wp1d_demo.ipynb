# %%
from wp1d import *

w1 = WienerProcess1D(10000)
w2 = WienerProcess1D(8000)
w3 = WienerProcess1D(6000)
d1 = Doamin1D(-5,5)
d2 = Doamin1D()
pr = ProcessRegister1D()
pr.add_process([w1,w2,w3])
pr.add_domain([d1,d2])

# %%
print(pr.get_exit_time())
# Out:
# [[3084.46 2642.97 4967.6 ]
#  [    nan     nan     nan]]

# %%
pr.plot_full_process()
plt.show()

# %%
pr.plot_up_to_exit()
plt.show()
